# %% [markdown]
# # Homework 2: Learning to use MLflow by a Duration Prediction model
# #### Abraham Alvarado Padilla

# %%
import os
import pickle
import click
import mlflow

import mlflow.sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

mlflow.set_experiment("Homework_2_experiment")

with mlflow.start_run():
    
    def load_pickle(filename: str):
        with open(filename, "rb") as f_in:
            return pickle.load(f_in)


    @click.command()
    @click.option(
        "--data_path",
        default="./output",
        help=r"C:\Users\mokon\Documents\Mlops-Zoomcamp\Homework_2\output"
    )
    def run_train(data_path: str):

        X_train, y_train = load_pickle(os.path.join(data_path, "train.pkl"))
        X_val, y_val = load_pickle(os.path.join(data_path, "val.pkl"))

        rf = RandomForestRegressor(max_depth=10, random_state=0)
        rf.fit(X_train, y_train)
        y_pred = rf.predict(X_val)
        mlflow.sklearn.log_model(rf, artifact_path= "Models_homework_2" )

        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metrics({"rmse": rmse})


    if __name__ == '__main__':
        run_train()
# Out:
# Usage: ipykernel_launcher.py [OPTIONS]
# Try 'ipykernel_launcher.py --help' for help.
#
# Error: No such option: --f
# ---------------------------------------------------------------------------
# NoSuchOption                              Traceback (most recent call last)
# File c:\Users\mokon\Documents\Anaconda\Lib\site-packages\click\core.py:1077, in BaseCommand.main(self, args, prog_name, complete_var, standalone_mode, windows_expand_args, **extra)
#    1076 try:
# -> 1077     with self.make_context(prog_name, args, **extra) as ctx:
#    1078         rv = self.invoke(ctx)
#
# File c:\Users\mokon\Documents\Anaconda\Lib\site-packages\click\core.py:943, in BaseCommand.make_context(self, info_name, args, parent, **extra)
#     942 with ctx.scope(cleanup=False):
# --> 943     self.parse_args(ctx, args)
#     944 return ctx
#
# File c:\Users\mokon\Documents\Anaconda\Lib\site-packages\click\core.py:1405, in Command.parse_args(self, ctx, args)
#    1404 parser = self.make_parser(ctx)
# ...
